# %% [markdown]
# # E-Commerce Python: Complete Practical Data Analysis and Machine Learning Challenge
#
# **Dataset:** `ecommerce_dataset.csv`
# **Goal:** Work from raw data to business decisions, visualization, feature engineering, statistical thinking, and machine learning.
#
# ## Rules for this notebook
# 1. **Attempt every challenge before looking anything up.**
# 2. For every analysis, answer:
#    - What did I do?
#    - Why did I do it?
#    - What did I find?
#    - What business or technical decision follows?
# 3. Do not run the whole notebook blindly. Work section by section.
# 4. Write your own code in every `YOUR CODE HERE` cell.
# 5. If stuck, inspect documentation or your notes, then return and rewrite the solution yourself.
# 6. Keep a short learning log after each major section.
#
# ## Dataset reality check
# This dataset has **1,000 rows and 12 columns**, with 246 unique customers, 10 products, 6 categories, 5 cities, 4 payment methods, and 4 order statuses. Dates span 2025-01-01 to 2025-12-31.
#
# This is a **small but useful practice dataset**. It is good for Python, pandas, EDA, visualization, feature engineering, business analysis, and learning the full ML workflow. It is **not large enough to prove production-grade ML performance**, and some fields may be synthetic or structurally deterministic. You must discover those limitations yourself.
#
# ---
#
# # Final deliverables
#
# By the end, you should be able to produce:
#
# 1. A data-quality report.
# 2. A cleaned analysis dataset.
# 3. A feature-engineered dataset.
# 4. A business KPI dashboard.
# 5. At least 10 meaningful visualizations.
# 6. A customer analysis.
# 7. A product/category/city/payment analysis.
# 8. A time-series analysis.
# 9. An outlier and anomaly investigation.
# 10. At least one statistically reasoned comparison.
# 11. A regression experiment.
# 12. A classification experiment.
# 13. A proper model evaluation and comparison.
# 14. An honest explanation of whether the models are actually useful.
# 15. Final business and technical recommendations.
#
# **Important:** A high model score is not automatically a good model. You must check leakage, baselines, validation design, and whether the prediction problem is meaningful.

# %% [markdown]
# ## 0. Setup and environment

# %%
# Run once if packages are missing:
# !pip install pandas numpy matplotlib scikit-learn scipy joblib

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from pathlib import Path

pd.set_option("display.max_columns", None)
pd.set_option("display.float_format", lambda x: f"{x:,.2f}")

RANDOM_STATE = 42
DATA_PATH = Path("ecommerce_dataset.csv")

assert DATA_PATH.exists(), f"File not found: {DATA_PATH.resolve()}"

df = pd.read_csv(DATA_PATH)

print("Shape:", df.shape)
display(df.head())

# %% [markdown]
# ## 1. Dataset understanding — do not skip
# Before cleaning anything, understand what each row represents and what each column means.

# %% [markdown]
# ### Challenge 1.1 — Schema inspection
# Without copying the output into a report manually:
# - display shape;
# - display dtypes;
# - calculate memory usage;
# - calculate unique values for every column;
# - create a data dictionary with: column name, dtype, non-null count, null count, unique count.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 1.2 — Identify the analytical grain
# Answer in your own words:
#
# **What does one row represent?**
#
# Use these questions:
# - Is one row one customer?
# - One order?
# - One product?
# - One order line?
# - Can one customer appear multiple times?
# - Can one order appear multiple times?
#
# Then prove your answer with code.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 1.3 — Categorical inspection
# For every categorical column:
# - count each category;
# - calculate percentages;
# - identify the least and most common values;
# - check suspicious spelling/capitalization/whitespace differences.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 2. Data quality and cleaning

# %% [markdown]
# ### Challenge 2.1 — Missing data
# Calculate:
# - missing count;
# - missing percentage;
# - rows containing at least one missing value.
#
# Then explain whether action is required.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 2.2 — Duplicate investigation
# Check:
# - exact duplicate rows;
# - duplicate `order_id`;
# - duplicate combinations you believe should be unique.
#
# Do not immediately drop duplicates. First explain why each duplicate type would or would not be a problem.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 2.3 — Data type correction
# Investigate whether `order_date` should remain an object.
#
# Convert it safely, then check:
# - conversion failures;
# - minimum date;
# - maximum date;
# - number of unique dates;
# - gaps or unexpected dates.
#
# Create a working copy called `df_clean`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 2.4 — Business-rule validation
# Test these possible rules:
# - quantity > 0;
# - unit_price > 0;
# - discount_percent is within a sensible range;
# - total_amount > 0;
# - order IDs are unique;
# - customer IDs are valid identifiers;
# - dates are valid;
# - order_status values are expected.
#
# Create a table of every failed rule and the number of affected rows.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 2.5 — Arithmetic consistency
# Investigate whether:
#
# `total_amount ≈ quantity × unit_price × (1 - discount_percent / 100)`
#
# Calculate:
# - expected total;
# - absolute difference;
# - relative difference;
# - maximum difference;
# - rows outside a reasonable rounding tolerance.
#
# Explain whether differences are likely rounding errors or data errors.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 2.6 — Suspicious relationships
# Check whether each product always belongs to one category.
#
# If not, investigate the conflicting rows.
#
# Then ask: should this dataset be cleaned, or should the inconsistency be preserved and reported?

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 3. Core pandas manipulation challenges

# %% [markdown]
# ### Challenge 3.1 — Selection and filtering
# Write code to:
# 1. select only Lagos orders;
# 2. select delivered orders;
# 3. select orders above the median total_amount;
# 4. select orders with discounts of at least 10%;
# 5. select orders matching at least three conditions;
# 6. select using `query()`;
# 7. solve one selection with boolean indexing and another with `.loc`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 3.2 — Sorting and ranking
# Create:
# - top 10 most expensive orders;
# - top 10 largest quantities;
# - top customers by total spending;
# - rank products by revenue;
# - rank cities by order count.
#
# Use both ascending and descending cases.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 3.3 — Groupby mastery
# Calculate by:
# - city;
# - product;
# - category;
# - payment method;
# - order status;
# - customer.
#
# For each, where meaningful, compute:
# - order count;
# - total revenue;
# - average order value;
# - total quantity;
# - median order value;
# - maximum order value.
#
# Create at least one multi-level groupby.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 3.4 — Aggregation design
# Create a reusable function that accepts a grouping column and returns a standardized KPI table.
#
# Example idea:
#
# `summary_by(df_clean, "city")`
#
# Your function should validate the requested column and raise a useful error if the column does not exist.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 3.5 — Transform, map, apply
# Solve one useful problem with each:
# - `.map()`;
# - `.apply()`;
# - `.transform()`.
#
# Then explain why `.transform()` is useful when you need a result aligned back to the original rows.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 4. Feature engineering

# %% [markdown]
# ### Challenge 4.1 — Date features
# Create:
# - year;
# - month number;
# - month name;
# - quarter;
# - day of week;
# - day name;
# - week of year;
# - weekend flag.
#
# Then verify that the new columns are correct.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 4.2 — Revenue and price features
# Create:
# - gross_amount = quantity × unit_price;
# - discount_amount;
# - net_amount;
# - effective_discount_rate;
# - order_value_band: Low / Medium / High using thresholds you justify.
#
# Do not overwrite the original `total_amount`.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 4.3 — Customer features
# At customer level, create:
# - number of orders;
# - total spending;
# - average order value;
# - total quantity;
# - favorite product;
# - favorite category;
# - first purchase date;
# - last purchase date;
# - active_days;
# - average discount received.
#
# Be explicit about how you handle ties.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 4.4 — RFM-style analysis
# Create a snapshot date one day after the maximum order date.
#
# For each customer calculate:
# - Recency;
# - Frequency;
# - Monetary value.
#
# Then create customer segments.
#
# Suggested starting segments:
# - Champions
# - Loyal
# - Big Spenders
# - At Risk
# - New / Low History
#
# You may redesign these rules, but document your logic.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 5. Exploratory data analysis

# %% [markdown]
# ### Challenge 5.1 — Numerical summary
# For every numerical column calculate:
# - count;
# - mean;
# - median;
# - standard deviation;
# - min;
# - max;
# - 25th percentile;
# - 75th percentile;
# - skewness.
#
# Identify at least three findings that are not obvious from `.describe()` alone.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 5.2 — Distribution analysis
# Create and interpret:
# 1. histogram of total_amount;
# 2. histogram of unit_price;
# 3. histogram of quantity;
# 4. histogram of discount_percent.
#
# For each, state:
# - shape;
# - center;
# - spread;
# - possible outliers;
# - practical implication.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 5.3 — Categorical distributions
# Visualize:
# - order count by city;
# - order count by category;
# - order count by payment method;
# - order count by order status;
# - product popularity.
#
# Do not make five identical charts blindly. Choose chart types deliberately.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 6. Visualization challenge

# %% [markdown]
# Create at least 10 visualizations. Every chart must answer a question.
#
# Required questions:
# 1. Which cities generate the most revenue?
# 2. Which products generate the most revenue?
# 3. Which products generate the most quantity sold?
# 4. Which categories have the highest average order value?
# 5. How does revenue change over time?
# 6. How do order counts change over time?
# 7. How are discounts distributed?
# 8. Does higher discount appear associated with higher quantity?
# 9. How does order value differ across cities?
# 10. What is the order-status distribution?
#
# Additional challenge:
# - Create at least one heatmap or correlation matrix.
# - Create at least one boxplot.
# - Create at least one scatter plot.
# - Create at least one multi-series time chart.
#
# For every visualization, write a markdown interpretation directly below it.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 7. Time-based analysis

# %% [markdown]
# ### Challenge 7.1 — Daily and monthly KPIs
# Calculate daily and monthly:
# - revenue;
# - orders;
# - unique customers;
# - average order value;
# - quantity sold;
# - average discount.
#
# Use a datetime index or pandas resampling where appropriate.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 7.2 — Growth
# Calculate:
# - day-over-day revenue growth;
# - month-over-month revenue growth;
# - rolling 7-day revenue;
# - rolling 30-day revenue.
#
# Investigate unstable percentage changes caused by small denominators.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 7.3 — Seasonality
# Compare performance by:
# - month;
# - day of week;
# - weekend vs weekday.
#
# State clearly whether the dataset contains enough evidence to claim real seasonality.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 8. Customer and business analysis

# %% [markdown]
# ### Challenge 8.1 — Customer concentration
# Calculate:
# - top 10 customers by spending;
# - their share of total revenue;
# - cumulative revenue share by ranked customers.
#
# Question: Is revenue concentrated among a small number of customers?

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 8.2 — Repeat behavior
# Calculate:
# - customers with one order;
# - customers with multiple orders;
# - repeat customer rate;
# - average order value for one-time vs repeat customers.
#
# Explain whether this dataset can support a meaningful retention conclusion.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 8.3 — Cancellation analysis
# Compare cancelled orders against non-cancelled orders by:
# - city;
# - product;
# - category;
# - payment method;
# - discount level;
# - order value.
#
# Do not conclude causation from simple differences.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 8.4 — Discount effectiveness
# Investigate:
# - average quantity by discount level;
# - average revenue by discount level;
# - average order value by discount level;
# - status distribution by discount level.
#
# Then answer: **Does this dataset provide evidence that larger discounts improve business outcomes?**

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 9. Outlier and anomaly investigation

# %% [markdown]
# ### Challenge 9.1 — IQR method
# For `total_amount` and `unit_price`:
# - calculate Q1 and Q3;
# - calculate IQR;
# - define lower and upper bounds;
# - count outliers;
# - inspect actual outlier rows.
#
# Do not automatically remove outliers.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 9.2 — Z-score or robust alternative
# Implement a second outlier method.
#
# Compare it with IQR:
# - how many rows does each method flag?
# - which rows overlap?
# - why might the results differ?

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 9.3 — Decision
# For each outlier type decide:
# - keep;
# - remove;
# - cap/winsorize;
# - investigate further.
#
# Defend the decision in business terms.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 10. Statistical thinking challenge

# %% [markdown]
# Choose one meaningful question, for example:
#
# - Do average order amounts differ between two cities?
# - Do cancelled and non-cancelled orders have different average discounts?
# - Does order value differ across categories?
#
# For your chosen question:
# 1. define H0 and H1;
# 2. inspect sample sizes;
# 3. inspect assumptions;
# 4. choose a test;
# 5. calculate the statistic and p-value;
# 6. report effect size if appropriate;
# 7. explain practical significance separately from statistical significance.
#
# **Do not run tests mechanically. Explain why the test fits the data.**

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 11. Machine learning: first decide whether ML is justified

# %% [markdown]
# This section is deliberately demanding.
#
# You have only 1,000 rows. ML is still useful as a learning exercise, but you must evaluate honestly.
#
# ### Critical question
# Before training any model, inspect whether the target can be derived directly from the input features.
#
# For example, if `total_amount` is mathematically calculated from `quantity`, `unit_price`, and `discount_percent`, then using those variables to predict `total_amount` creates **target leakage**. A near-perfect score in that setup would not demonstrate useful prediction.
#
# Your first ML task is therefore to design a prediction problem that makes sense.

# %% [markdown]
# ## 12. Regression experiment

# %% [markdown]
# ### Challenge 12.1 — Target design
# Candidate target: `total_amount`.
#
# Create two experiments:
#
# **Experiment A: intentionally investigate leakage**
# - Use `quantity`, `unit_price`, and `discount_percent`.
# - Train a simple regression model.
# - Explain why this experiment is not a valid demonstration of predictive intelligence if the target is derived from those variables.
#
# **Experiment B: leakage-aware**
# Design a more realistic feature set by excluding direct deterministic components where possible.
#
# You must explain whether the remaining dataset contains enough signal to make this a useful regression problem.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 12.2 — Baseline
# Create a baseline predictor, such as predicting the training mean.
#
# Calculate MAE, RMSE, and R² for the baseline.
#
# A model is only interesting if you compare it against a baseline.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 12.3 — Preprocessing pipeline
# Build preprocessing with:
# - numeric features;
# - categorical features;
# - appropriate transformations;
# - `ColumnTransformer`;
# - `Pipeline`.
#
# Split data before fitting preprocessing.
#
# Use a fixed random state for reproducibility.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 12.4 — Compare models
# Compare at least:
# - LinearRegression;
# - RandomForestRegressor;
# - HistGradientBoostingRegressor or another justified model.
#
# Create a comparison table with:
# - CV mean;
# - CV standard deviation;
# - test MAE;
# - test RMSE;
# - test R²;
# - training score if useful.
#
# Then explain whether any score may be misleading.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 12.5 — Error analysis
# For the best regression candidate:
# - create predicted vs actual plot;
# - calculate residuals;
# - inspect largest errors;
# - identify whether errors cluster by city/product/category;
# - explain what information the dataset may be missing.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 13. Classification experiment: predict order_status

# %% [markdown]
# ### Challenge 13.1 — Inspect the target
# Calculate:
# - class counts;
# - class percentages;
# - majority-class baseline.
#
# Ask: are classes balanced enough for accuracy to be meaningful?

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 13.2 — Time-aware feature design
# Do not use `order_id` as a feature unless you can justify it.
#
# Create reasonable features from:
# - date;
# - quantity;
# - price;
# - discount;
# - city;
# - product/category;
# - payment method.
#
# Then explain why each feature could plausibly be available at prediction time.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 13.3 — Classification pipeline
# Build a pipeline with:
# - train/test split using stratification if appropriate;
# - preprocessing;
# - at least two classifiers.
#
# Suggested models:
# - LogisticRegression;
# - RandomForestClassifier;
# - HistGradientBoostingClassifier where compatible with your preprocessing.
#
# Evaluate:
# - accuracy;
# - balanced accuracy;
# - precision;
# - recall;
# - F1;
# - confusion matrix;
# - classification report.
#
# Do not rely on accuracy alone.

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 13.4 — Baseline comparison
# Compare your models against a `DummyClassifier`.
#
# Question:
# **Is your model genuinely learning useful structure, or simply exploiting class imbalance?**

# %%
# YOUR CODE HERE

# %% [markdown]
# ### Challenge 13.5 — Cross-validation
# Perform cross-validation on the training data only.
#
# Report mean and standard deviation.
#
# Keep the test set untouched until final evaluation.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 14. Model debugging and trustworthiness

# %% [markdown]
# For your best model, answer all of the following:
#
# 1. What exactly is the prediction target?
# 2. What information is available when the prediction would be made?
# 3. Could any feature leak the answer?
# 4. What baseline did you beat?
# 5. How does cross-validation compare with the final test score?
# 6. Are errors concentrated in particular groups?
# 7. Which classes or cases fail most often?
# 8. What would happen if the real-world data distribution changed?
# 9. Is the dataset large and representative enough?
# 10. Would you deploy this model? Why or why not?
#
# **A model that appears correct on a few examples is not automatically performing well.**

# %%
# WRITE YOUR ANSWERS HERE

# %% [markdown]
# ## 15. Model interpretation

# %% [markdown]
# For a model that supports feature importance:
# - inspect feature importance;
# - identify the most influential features;
# - check whether the result is plausible;
# - beware that importance does not prove causation.
#
# If using transformed one-hot encoded features, make sure you can map feature names back to understandable labels.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 16. Advanced feature engineering challenges

# %% [markdown]
# Try as many as possible:
#
# 1. Customer average historical spending, calculated without using the current order.
# 2. Customer prior order count.
# 3. Product historical average order value, calculated leakage-safely.
# 4. Customer-product interaction features.
# 5. Discount bands.
# 6. Price bands.
# 7. Monthly category performance.
# 8. Lag features for time analysis where valid.
# 9. Expanding customer features.
# 10. Frequency encoding or carefully designed categorical encodings.
#
# For each feature, answer:
# - Is it available at prediction time?
# - Could it leak future information?
# - Does it improve validation performance?

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 17. Optional: leakage-safe historical validation

# %% [markdown]
# Because this dataset has dates across a year, perform an advanced experiment:
#
# - sort by date;
# - train on earlier dates;
# - validate/test on later dates;
# - compare this with a random split.
#
# Question:
# **Which evaluation better represents future prediction, and why?**
#
# Do not use future information when constructing historical features.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 18. Optional: hyperparameter tuning

# %% [markdown]
# Only do this after you have:
# - a meaningful problem;
# - a baseline;
# - a correct validation strategy;
# - a working pipeline.
#
# Use RandomizedSearchCV or GridSearchCV on the training data.
#
# Do not tune repeatedly on the final test set.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 19. Reusable functions and code quality

# %% [markdown]
# Refactor repeated logic into functions.
#
# Suggested functions:
# - `data_quality_report(df)`
# - `summary_by(df, column)`
# - `plot_top_revenue(df, column, n=10)`
# - `evaluate_regression(y_true, y_pred)`
# - `evaluate_classifier(y_true, y_pred)`
# - `make_features(df)`
# - `compare_models(...)`
#
# Add:
# - docstrings;
# - useful error messages;
# - assertions where appropriate.
#
# Your goal is not just to get output. Your code should be reusable.

# %%
# YOUR CODE HERE

# %% [markdown]
# ## 20. Final project report

# %% [markdown]
# Write your final report in this structure.
#
# ### 1. Business objective
# What questions did you investigate?
#
# ### 2. Dataset
# What does each row represent? What are the key columns?
#
# ### 3. Data quality
# What problems did you check? What did you find? What did you change?
#
# ### 4. Exploratory findings
# Give your five most important findings.
#
# ### 5. Customer findings
# Who are the most valuable customers? Is revenue concentrated? What segments did you find?
#
# ### 6. Product/category findings
# What performs best and worst?
#
# ### 7. Geographic findings
# How do cities differ?
#
# ### 8. Discount findings
# What does the evidence suggest, and what does it not prove?
#
# ### 9. Time findings
# What trends or possible seasonal patterns did you find?
#
# ### 10. ML problem design
# What did you try to predict, and why?
#
# ### 11. Leakage and validity
# What leakage risks did you identify?
#
# ### 12. Model results
# Compare baseline and models.
#
# ### 13. Error analysis
# Where does the model fail?
#
# ### 14. Decision
# Would you use the model in production?
#
# ### 15. Next data needed
# What additional real-world columns would make this project substantially better?
#
# ### 16. Final recommendations
# Give 5 concrete business recommendations and 3 technical/data recommendations.

# %%
# WRITE YOUR FINAL REPORT HERE

# %% [markdown]
# # Completion checklist
#
# Do not mark the project complete until you can independently explain:
#
# - [ ] What one row represents.
# - [ ] Every important column and its dtype.
# - [ ] How you checked data quality.
# - [ ] Why dates were converted.
# - [ ] Why groupby is useful.
# - [ ] Why each major visualization exists.
# - [ ] What your strongest business findings are.
# - [ ] What an outlier is and why you did or did not remove it.
# - [ ] Why correlation does not prove causation.
# - [ ] What target leakage is.
# - [ ] Why a baseline is necessary.
# - [ ] Why train/test splitting matters.
# - [ ] Why cross-validation matters.
# - [ ] Why accuracy alone can mislead.
# - [ ] How to inspect a confusion matrix.
# - [ ] How to inspect regression errors.
# - [ ] Whether your model is genuinely useful.
# - [ ] What data limitations prevent stronger conclusions.
# - [ ] What you would do next with more realistic data.
#
# ## Stretch goal
# After completing this notebook without copying solutions, rebuild the entire analysis from a blank notebook using only your own understanding and documentation.
