# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect("store.db")

print("✅ Connected to store.db")
# Out:
# ✅ Connected to store.db

# %%
# Connect to Database
def run_sql(query):
    return pd.read_sql(query, conn)

# %%
run_sql("""
    SELECT * FROM customers
""")
# Out:
#    id            name              email           city
# 0   1   Alice Johnson  alice@example.com          Lagos
# 1   2       Bob Smith    bob@example.com          Abuja
# 2   3  Carol Williams  carol@example.com          Lagos
# 3   4     David Brown  david@example.com         Ibadan
# 4   5       Eva Davis    eva@example.com          Abuja
# 5   6    Frank Wilson  frank@example.com  Port Harcourt
# 6   7    Grace Taylor  grace@example.com          Lagos
# 7   8     Henry Moore  henry@example.com           Kano
